# %%
import pandas as pd

# %%
# 读取csv
am=pd.read_csv("./amazon.csv")
am
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
am.head(10)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# 5  B08Y1TFSP6  pTron Solero TB301 3A Type-C Data and Fast Cha...
# 6  B08WRWPM22  boAt Micro USB 55 Tangle-free, Sturdy Micro US...
# 7  B08DDRGWTJ             MI Usb Type-C Cable Smartphone (Black)
# 8  B008IFXQFU  TP-Link USB WiFi Adapter for PC(TL-WN725N), N1...
# 9  B082LZGK39  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# ...

# %%
am.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
# 随机返回参数
am.sample(10)
# Out:
#       product_id                                       product_name  \
# 737   B01N4EV2TL  Logitech MK240 Nano Wireless USB Keyboard and ...
# 1410  B075S9FVRY  Sujata Supermix, Mixer Grinder, 900 Watts, 3 J...
# 58    B0B4DT8MKT  Wecool Unbreakable 3 in 1 Charging Cable with ...
# 670   B0856HNMR7  boAt Rockerz 370 On Ear Bluetooth Headphones w...
# 956   B07W9KYT62  TP-Link AC1200 Archer A6 Smart WiFi, 5GHz Giga...
# 273   B08PZ6HZLT  VW 80 cm (32 inches) HD Ready Android Smart LE...
# 30    B00NH11PEY  AmazonBasics USB 2.0 - A-Male to A-Female Exte...
# 264   B09LQQYNZQ                           Realme Smart TV Stick 4K
# 123   B099K9ZX65  Hisense 108 cm (43 inches) 4K Ultra HD Smart C...
# 477   B0B56YRBNT  Tecno Spark 9 (Sky Mirror, 6GB RAM,128GB Stora...
#
#                                                category discounted_price  \
# 737   Computers&Accessories|Accessories&Peripherals|...           ₹1,495
# ...

# %%
# 扩展列
pd.set_option("display.max_columns",150)

# %%
pd.set_option("display.max_colwidth",500)

# %%
am
# Out:
#       product_id  \
# 0     B07JW9H4J1
# 1     B098NS6PVG
# 2     B096MSW6CT
# 3     B08HDJ86NZ
# 4     B08CF3B7N1
# ...          ...
# 1460  B08L7J3T31
# 1461  B01M6453MB
# 1462  B009P2LIL4
# 1463  B00J5DYCCA
# 1464  B01486F4G6
#
#                                                                                                                                                                                                  product_name  \
# 0                                          Wayona Nylon Braided USB to Lightning Fast Charging and Data Sync Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini (3 FT Pack of 1, Grey)
# 1           Ambrane Unbreakable 60W / 3A Fast Charging 1.5m Braided Type C Cable for Smartphones, Tablets, Laptops & other Type C devices, PD Technology, 480Mbps Data Sync, Quick Charge 3.0 (RCT15A, Black)
# ...

# %%
# 如何发现丢失数据 直接办法
am.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
# isnull检查值是否为空缺值
am["product_id"].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: product_id, Length: 1465, dtype: bool

# %%
am["product_id"].isnull().sum()
# Out:
# 0

# %%
# 可以查到丢失空缺数据的行
am[am["product_id"].isnull()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, discounted_price, actual_price, discount_percentage, rating, rating_count, about_product, user_id, user_name, review_id, review_title, review_content, img_link, product_link]
# Index: []

# %%
# 重复数据
am["product_id"].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: product_id, Length: 1465, dtype: bool

# %%
# 查询学生 多个变量是否重复
# students.duplicated(subset=["学号"，"性别"])

# %%
# 通过条件提取重复行
# students[students.duplicated(subset=["学号"，"性别"])]

# %%
# 不一致数据
# students["班级"]
# students["班级"].value_counts()

# %%
# 评估无效/错误数据
# 通过series的sort_values()方法
# students["身高"].sort_values()
# stundents.describe()
